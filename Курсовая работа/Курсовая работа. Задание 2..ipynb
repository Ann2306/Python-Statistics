# %%
#импорт библиотек
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
import scipy
from scipy import stats
from scipy.stats import levene
import numpy as np
import sklearn
from sklearn import datasets
from scipy.stats import bartlett
from matplotlib.colors import LinearSegmentedColormap
from scipy.stats import chi2_contingency

# %%
#импорт данных
df = pd.read_excel('variant_40.xlsx', sheet_name='v40_2')
df = pd.DataFrame(df)
df.head()
# Out:
#   Group  Value
# 0     A      0
# 1     A      1
# 2     A      1
# 3     A      1
# 4     A      0

# %%
#Таблица сопряженности 
contigency= pd.crosstab(df['Group'], df['Value'])
contigency
# Out:
# Value  0  1
# Group
# A      4  9
# B      8  5

# %%
#Тест Фишера
from scipy.stats import fisher_exact
oddsratio, p = fisher_exact(contigency)
print ('p-value',p)
# Out:
# p-value 0.23774397630905902

# %% [markdown]
# ##### Значение p=23,8 %, что означает, что мы не отвергаем нулевую гипотезу, при уровне достоверности 95%. Нулевая гепотеза заключается в том, что А и В независимы.

# %%
#Построение гистограммы частот
import matplotlib.pyplot as plt
import matplotlib

from matplotlib.colors import LinearSegmentedColormap

matplotlib.style.use('ggplot')


a_b = ('Group', '1', '0')

data1 = [["A", 9, 4],
         ["B", 5, 8]]


data2 = pd.DataFrame(data=data1)
data2.columns = a_b
data2 = data2.set_index('Group')
data2.plot(kind='bar', stacked=True, color=['green', 'yellow'])
plt.show()
